# %%
import torch
import numpy as np
import pandas as pd
import sklearn
import scipy

# 1. PyTorch
print(f"✅ PyTorch:    {torch.__version__}")

# 2. MPS check (no crash — just checking availability)
print(f"✅ MPS built:  {torch.backends.mps.is_built()}")
print(f"✅ MPS avail:  {torch.backends.mps.is_available()}")

# 3. Device selection
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"✅ Device:     {device}")

# 4. Safe tensor test (tiny — won't crash)
t = torch.tensor([1.0, 2.0, 3.0]).to(device)
print(f"✅ Tensor:     {t} on {t.device}")

# 5. Other libraries
print(f"✅ NumPy:      {np.__version__}")
print(f"✅ Pandas:     {pd.__version__}")
print(f"✅ Sklearn:    {sklearn.__version__}")
print(f"✅ SciPy:      {scipy.__version__}")

print("\n🚀 Environment fully ready for battery RUL project!")
# Out:
# ✅ PyTorch:    2.10.0
# ✅ MPS built:  True
# ✅ MPS avail:  True
# ✅ Device:     mps
# ✅ Tensor:     tensor([1., 2., 3.], device='mps:0') on mps:0
# ✅ NumPy:      2.4.2
# ✅ Pandas:     3.0.1
# ✅ Sklearn:    1.8.0
# ✅ SciPy:      1.17.1
#
# 🚀 Environment fully ready for battery RUL project!
